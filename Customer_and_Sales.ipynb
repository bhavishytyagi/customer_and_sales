# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cust=pd.read_csv('/content/drive/MyDrive/customer_data.csv')
cust
# Out:
#       customer_id  gender   age payment_method
# 0         C241288  Female  28.0    Credit Card
# 1         C111565    Male  21.0     Debit Card
# 2         C266599    Male  20.0           Cash
# 3         C988172  Female  66.0    Credit Card
# 4         C189076  Female  53.0           Cash
# ...           ...     ...   ...            ...
# 99452     C441542  Female  45.0    Credit Card
# 99453     C569580    Male  27.0           Cash
# 99454     C103292    Male  63.0     Debit Card
# 99455     C800631    Male  56.0           Cash
# 99456     C273973  Female  36.0    Credit Card
#
# [99457 rows x 4 columns]

# %%
sales=pd.read_csv('/content/drive/MyDrive/sales_data.csv')
sales
# Out:
#       invoice_no customer_id         category  quantity    price invoice_date  \
# 0        I138884     C241288         Clothing         5  1500.40   05-08-2022
# 1        I317333     C111565            Shoes         3  1800.51   12-12-2021
# 2        I127801     C266599         Clothing         1   300.08   09-11-2021
# 3        I173702     C988172            Shoes         5  3000.85   16-05-2021
# 4        I337046     C189076            Books         4    60.60   24-10-2021
# ...          ...         ...              ...       ...      ...          ...
# 99452    I219422     C441542         Souvenir         5    58.65   21-09-2022
# 99453    I325143     C569580  Food & Beverage         2    10.46   22-09-2021
# 99454    I824010     C103292  Food & Beverage         2    10.46   28-03-2021
# 99455    I702964     C800631       Technology         4  4200.00   16-03-2021
# 99456    I232867     C273973         Souvenir         3    35.19   15-10-2022
#
#           shopping_mall
# ...

# %%
new=pd.merge(left=cust,right=sales)
new
# Out:
#       customer_id  gender   age payment_method invoice_no         category  \
# 0         C241288  Female  28.0    Credit Card    I138884         Clothing
# 1         C111565    Male  21.0     Debit Card    I317333            Shoes
# 2         C266599    Male  20.0           Cash    I127801         Clothing
# 3         C988172  Female  66.0    Credit Card    I173702            Shoes
# 4         C189076  Female  53.0           Cash    I337046            Books
# ...           ...     ...   ...            ...        ...              ...
# 99452     C441542  Female  45.0    Credit Card    I219422         Souvenir
# 99453     C569580    Male  27.0           Cash    I325143  Food & Beverage
# 99454     C103292    Male  63.0     Debit Card    I824010  Food & Beverage
# 99455     C800631    Male  56.0           Cash    I702964       Technology
# 99456     C273973  Female  36.0    Credit Card    I232867         Souvenir
#
#        quantity    price invoice_date     shopping_mall
# ...

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     99457 non-null  object
#  1   gender          99457 non-null  object
#  2   age             99338 non-null  float64
#  3   payment_method  99457 non-null  object
#  4   invoice_no      99457 non-null  object
#  5   category        99457 non-null  object
#  6   quantity        99457 non-null  int64
#  7   price           99457 non-null  float64
#  8   invoice_date    99457 non-null  object
#  9   shopping_mall   99457 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 8.3+ MB

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     99457 non-null  object
#  1   gender          99457 non-null  object
#  2   age             99338 non-null  float64
#  3   payment_method  99457 non-null  object
#  4   invoice_no      99457 non-null  object
#  5   category        99457 non-null  object
#  6   quantity        99457 non-null  int64
#  7   price           99457 non-null  float64
#  8   invoice_date    99457 non-null  object
#  9   shopping_mall   99457 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 8.3+ MB

# %%
new.shape
# Out:
# (99457, 10)

# %%
new.describe()
# Out:
#                 age      quantity         price
# count  99338.000000  99457.000000  99457.000000
# mean      43.425859      3.003429    689.256321
# std       14.989400      1.413025    941.184567
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     99457 non-null  object
#  1   gender          99457 non-null  object
#  2   age             99338 non-null  float64
#  3   payment_method  99457 non-null  object
#  4   invoice_no      99457 non-null  object
#  5   category        99457 non-null  object
#  6   quantity        99457 non-null  int64
#  7   price           99457 non-null  float64
#  8   invoice_date    99457 non-null  object
#  9   shopping_mall   99457 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 8.3+ MB

# %% [markdown]
# Check whether there is any duplicates or not...

# %%
new[new.duplicated(keep='last')]
# Out:
# Empty DataFrame
# Columns: [customer_id, gender, age, payment_method, invoice_no, category, quantity, price, invoice_date, shopping_mall]
# Index: []

# %% [markdown]
# There is no any duplicates in the dataframe

# %% [markdown]
# EDA

# %% [markdown]
# Number of Customers by their payment method

# %%
pc=new.groupby(['payment_method'],as_index=False)['customer_id'].count()
pc
# Out:
#   payment_method  customer_id
# 0           Cash        44447
# 1    Credit Card        34931
# 2     Debit Card        20079

# %%
plt.pie(data=pc,x='customer_id',labels='payment_method',autopct='%1.1f%%',explode=(0.02,0.02,0.02))
plt.gcf().gca().add_artist(plt.Circle((0,0),0.0,fc='white'))
plt.title('Payment Category')
plt.show()

# %% [markdown]
# Number of sales by Gender

# %%
gen_sale=new.groupby(['gender'],as_index=False)['customer_id'].count()
gen_sale
# Out:
#    gender  customer_id
# 0  Female        59482
# 1    Male        39975

# %%
ax=sns.barplot(x='gender',y='customer_id',data=gen_sale)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
gen_amt=new.groupby(['gender'],as_index=False)['price'].sum()
gen_amt
# Out:
#    gender        price
# 0  Female  40931801.62
# 1    Male  27619564.29

# %%
ax=sns.barplot(y='gender',x='price',data=gen_amt,palette=['Red','Orange'])
for bars in ax.containers:
  ax.bar_label(bars)

# %% [markdown]
# age_bucket

# %%
def conditions(i):
    if i <=20: return '0-20'
    if i > 20 and i <=30: return '20-30'
    if i > 30 and i <=40: return '30-40'
    if i > 40 and i <=50: return '40-50'
    if i > 50 and i <=60: return '50-60'
    if i > 60 and i <=70: return '60-70'
    if i > 70: return '>70'
    else : return 'Unavailable'

new['age_gp']=new['age'].apply(conditions)

# %%
new
# Out:
#       customer_id  gender   age payment_method invoice_no         category  \
# 0         C241288  Female  28.0    Credit Card    I138884         Clothing
# 1         C111565    Male  21.0     Debit Card    I317333            Shoes
# 2         C266599    Male  20.0           Cash    I127801         Clothing
# 3         C988172  Female  66.0    Credit Card    I173702            Shoes
# 4         C189076  Female  53.0           Cash    I337046            Books
# ...           ...     ...   ...            ...        ...              ...
# 99452     C441542  Female  45.0    Credit Card    I219422         Souvenir
# 99453     C569580    Male  27.0           Cash    I325143  Food & Beverage
# 99454     C103292    Male  63.0     Debit Card    I824010  Food & Beverage
# 99455     C800631    Male  56.0           Cash    I702964       Technology
# 99456     C273973  Female  36.0    Credit Card    I232867         Souvenir
#
#        quantity    price invoice_date     shopping_mall age_gp
# ...

# %% [markdown]
# Number of sales according to age

# %%
age=new.groupby(['age_gp'],as_index=False)['customer_id'].count()
age
# Out:
#         age_gp  customer_id
# 0         0-20         5617
# 1        20-30        19378
# 2        30-40        19245
# 3        40-50        19044
# 4        50-60        18907
# 5        60-70        17147
# 6  Unavailable          119

# %%
ax=sns.barplot(x='age_gp',y='customer_id',data=age)
for bars in ax.containers:
  ax.bar_label(bars)

# %% [markdown]
# Sales acc to categories

# %%
cat_sales=new.groupby(['category'],as_index=False)['price'].sum()
cat_sales
# Out:
#           category        price
# 0            Books    226977.30
# 1         Clothing  31075684.64
# 2        Cosmetics   1848606.90
# 3  Food & Beverage    231568.71
# 4            Shoes  18135336.89
# 5         Souvenir    174436.83
# 6       Technology  15772050.00
# 7             Toys   1086704.64

# %%
plt.figure(figsize=(12,4))
ax=sns.barplot(x='category',y='price',data=cat_sales)
for bars in ax.containers:
  ax.bar_label(bars)
plt.show()

# %% [markdown]
# Sales acc. to date

# %%
new['year']=pd.DatetimeIndex(new['invoice_date']).year
new
# Out:
# <ipython-input-23-6be7b5e1992f>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   new['year']=pd.DatetimeIndex(new['invoice_date']).year
#       customer_id  gender   age payment_method invoice_no         category  \
# 0         C241288  Female  28.0    Credit Card    I138884         Clothing
# 1         C111565    Male  21.0     Debit Card    I317333            Shoes
# 2         C266599    Male  20.0           Cash    I127801         Clothing
# 3         C988172  Female  66.0    Credit Card    I173702            Shoes
# 4         C189076  Female  53.0           Cash    I337046            Books
# ...           ...     ...   ...            ...        ...              ...
# 99452     C441542  Female  45.0    Credit Card    I219422         Souvenir
# 99453     C569580    Male  27.0           Cash    I325143  Food & Beverage
# ...

# %%
sales_date=new.groupby(['year'],as_index=False)['customer_id'].count()
sales_date
# Out:
#    year  customer_id
# 0  2021        45382
# 1  2022        45551
# 2  2023         8524

# %%
plt.pie(data=sales_date,x='customer_id',labels='year',autopct='%1.1f%%',pctdistance=0.75,explode=(0.05,0.05,0.05))
cc=plt.Circle((0,0),0.50,fc='white')
plt.gcf().gca().add_artist(cc)
plt.title('Yearwise Sales')
plt.show()

# %% [markdown]
# no. of sales per shopping mall

# %%
mall=new.groupby(['shopping_mall'],as_index=False)['customer_id'].count().sort_values(by='customer_id',ascending=False)
mall
# Out:
#        shopping_mall  customer_id
# 5   Mall of Istanbul        19943
# 4             Kanyon        19823
# 6          Metrocity        15011
# 7       Metropol AVM        10161
# 3       Istinye Park         9781
# 9       Zorlu Center         5075
# 0        Cevahir AVM         4991
# 2     Forum Istanbul         4947
# 8     Viaport Outlet         4914
# 1  Emaar Square Mall         4811

# %%
plt.figure(figsize=(14,4))
ax=sns.barplot(y='shopping_mall',x='customer_id',data=mall,palette=['magenta'])
for bars in ax.containers:
  ax.bar_label(bars)
plt.show()
